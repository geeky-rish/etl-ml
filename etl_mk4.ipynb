# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import urllib.request
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.cluster import KMeans
from sklearn.ensemble import IsolationForest
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure
import warnings

warnings.filterwarnings("ignore")

# MongoDB Configuration
MONGO_URI = "mongodb+srv://<etl_mk4>:<etl_mark4>@first.t3tgs.mongodb.net/?retryWrites=true&w=majority&appName=first"
DATABASE_NAME = "ETL_Project"
COLLECTION_NAME = "ProcessedData"

# Connect to MongoDB
def connect_mongo():
    try:
        client = MongoClient(MONGO_URI)
        db = client[DATABASE_NAME]
        print("✅ Connected to MongoDB successfully!")
        return db
    except ConnectionFailure as e:
        print(f"❌ MongoDB Connection Failed: {e}")
        return None

# Fetch Dataset from URL
def fetch_data():
    dataset_url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
    local_file = "data.csv"

    try:
        urllib.request.urlretrieve(dataset_url, local_file)
        print("✅ Dataset fetched successfully!")
        df = pd.read_csv(local_file)
        return df
    except Exception as e:
        print(f"❌ Data Fetching Failed: {e}")
        return None

# Data Cleaning
def clean_data(df):
    try:
        # Drop unwanted columns
        df.drop(["Name", "Ticket", "Cabin"], axis=1, inplace=True)

        # Convert categorical columns
        label_cols = ["Sex", "Embarked"]
        for col in label_cols:
            df[col] = LabelEncoder().fit_transform(df[col].astype(str))

        # Handle missing values using KNN Imputer
        imputer = KNNImputer(n_neighbors=5)
        df.iloc[:, :] = imputer.fit_transform(df)

        print("✅ Data Cleaning Successful!")
        return df
    except Exception as e:
        print(f"❌ Data Cleaning Failed: {e}")
        return None

# Data Transformation
def transform_data(df):
    try:
        # Standardize the data
        scaler = StandardScaler()
        df.iloc[:, :] = scaler.fit_transform(df)

        print("✅ Data Transformation Successful!")
        return df
    except Exception as e:
        print(f"❌ Data Transformation Failed: {e}")
        return None

# Optuna Objective Function
def objective(trial):
    try:
        # Suggest values for hyperparameters
        n_clusters = trial.suggest_int("n_clusters", 2, 10)  # Tune number of clusters
        contamination = trial.suggest_float("contamination", 0.01, 0.2)  # Tune outlier percentage

        # Load and preprocess data
        df = fetch_data()
        df = clean_data(df)
        df = transform_data(df)

        # Outlier Removal
        iso = IsolationForest(contamination=contamination, random_state=42)
        df["Anomaly"] = iso.fit_predict(df)
        df = df[df["Anomaly"] == 1]  # Keep only normal data
        df.drop(columns=["Anomaly"], inplace=True)

        # Clustering
        kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)
        df['Cluster'] = kmeans.fit_predict(df)

        return -kmeans.inertia_  # Minimize inertia for better clustering

    except Exception as e:
        print(f"❌ Optuna Optimization Failed: {e}")
        return float('inf')  # Return a large value to avoid stopping optimization

# Run Optuna optimization
study = optuna.create_study(direction="minimize")  # Minimize inertia
study.optimize(objective, n_trials=20)  # Run 20 trials

# Get best hyperparameters
best_params = study.best_params
n_clusters = best_params["n_clusters"]
contamination = best_params["contamination"]

print(f"✅ Best Parameters Found: {best_params}")

# Outlier Detection using Optimized Isolation Forest
def detect_outliers(df):
    try:
        iso = IsolationForest(contamination=contamination, random_state=42)
        df["Anomaly"] = iso.fit_predict(df)
        df = df[df["Anomaly"] == 1]  # Keep normal data
        df.drop(columns=["Anomaly"], inplace=True)

        print(f"✅ Outliers removed successfully using contamination={contamination}!")
        return df
    except Exception as e:
        print(f"❌ Outlier Detection Failed: {e}")
        return None

# Clustering using Optimized K-Means
def cluster_data(df):
    try:
        kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)
        df['Cluster'] = kmeans.fit_predict(df)

        print(f"✅ Clustering Successful with n_clusters={n_clusters}!")
        return df
    except Exception as e:
        print(f"❌ Clustering Failed: {e}")
        return None


# Save to MongoDB
def save_to_mongo(db, df):
    try:
        records = df.to_dict(orient="records")
        db[COLLECTION_NAME].insert_many(records)
        print("✅ Data saved to MongoDB successfully!")
    except Exception as e:
        print(f"❌ Data Saving Failed: {e}")

# Data Visualization
def visualize_data(df):
    try:
        sns.set_style("whitegrid")

        # 1. Cluster Distribution
        plt.figure(figsize=(8, 5))
        sns.countplot(x="Cluster", data=df, palette="coolwarm")
        plt.title("Cluster Distribution")
        plt.xlabel("Cluster")
        plt.ylabel("Count")
        plt.show()

        # 2. Correlation Heatmap
        plt.figure(figsize=(10, 6))
        sns.heatmap(df.corr(), annot=True, cmap="coolwarm", linewidths=0.5)
        plt.title("Feature Correlation Heatmap")
        plt.show()

        # 3. Histogram of Features
        df.hist(figsize=(12, 8), bins=30, color="skyblue")
        plt.suptitle("Feature Distributions")
        plt.show()

        # 4. Pairplot of Clusters
        sns.pairplot(df, hue="Cluster", palette="coolwarm")
        plt.show()

        print("✅ Visualization Complete!")
    except Exception as e:
        print(f"❌ Visualization Failed: {e}")

# Statistical Analysis
def statistical_analysis(df):
    try:
        print("\n📊 **Statistical Analysis:**")
        print(df.describe())

        print("\n🔢 **Feature Correlation:**")
        print(df.corr())

        print("✅ Statistical Analysis Complete!")
    except Exception as e:
        print(f"❌ Statistical Analysis Failed: {e}")

# Main Function
def main():
    db = connect_mongo()
    if db is None:
        return

    df = fetch_data()
    if df is None:
        return

    df = clean_data(df)
    if df is None:
        return

    df = transform_data(df)
    if df is None:
        return

    df = detect_outliers(df)
    if df is None:
        return

    df = cluster_data(df)
    if df is None:
        return

    save_to_mongo(db, df)
    visualize_data(df)
    statistical_analysis(df)

if __name__ == "__main__":
    main()
# Out:
# [I 2025-03-06 09:02:50,575] A new study created in memory with name: no-name-75ae04cb-7753-440a-b06b-2ce9ba86732b
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# [I 2025-03-06 09:02:50,890] Trial 0 finished with value: -3084.6433840925197 and parameters: {'n_clusters': 7, 'contamination': 0.05158105618041796}. Best is trial 0 with value: -3084.6433840925197.
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# [I 2025-03-06 09:02:51,188] Trial 1 finished with value: -3427.540442764786 and parameters: {'n_clusters': 4, 'contamination': 0.10055742898060828}. Best is trial 1 with value: -3427.540442764786.
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# [I 2025-03-06 09:02:51,495] Trial 2 finished with value: -2933.9679710648397 and parameters: {'n_clusters': 4, 'contamination': 0.15143279319258887}. Best is trial 1 with value: -3427.540442764786.
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# [I 2025-03-06 09:02:51,819] Trial 3 finished with value: -1918.521942854695 and parameters: {'n_clusters': 10, 'contamination': 0.14264644053580647}. Best is trial 1 with value: -3427.540442764786.
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# [I 2025-03-06 09:02:52,140] Trial 4 finished with value: -1872.565111218042 and parameters: {'n_clusters': 10, 'contamination': 0.15933498698401047}. Best is trial 1 with value: -3427.540442764786.
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# [I 2025-03-06 09:02:52,457] Trial 5 finished with value: -3085.5279652786235 and parameters: {'n_clusters': 3, 'contamination': 0.1729878553671465}. Best is trial 1 with value: -3427.540442764786.
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# [I 2025-03-06 09:02:52,751] Trial 6 finished with value: -2398.2702018397476 and parameters: {'n_clusters': 5, 'contamination': 0.18820379892349523}. Best is trial 1 with value: -3427.540442764786.
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# [I 2025-03-06 09:02:53,055] Trial 7 finished with value: -4025.0160105441187 and parameters: {'n_clusters': 4, 'contamination': 0.049067805830532295}. Best is trial 7 with value: -4025.0160105441187.
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# [I 2025-03-06 09:02:53,361] Trial 8 finished with value: -2646.1184711676433 and parameters: {'n_clusters': 8, 'contamination': 0.07764313599735924}. Best is trial 7 with value: -4025.0160105441187.
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# [I 2025-03-06 09:02:53,664] Trial 9 finished with value: -3920.2122601345 and parameters: {'n_clusters': 3, 'contamination': 0.08838316675237973}. Best is trial 7 with value: -4025.0160105441187.
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# [I 2025-03-06 09:02:53,974] Trial 10 finished with value: -5965.3822188922995 and parameters: {'n_clusters': 2, 'contamination': 0.014373455305978458}. Best is trial 10 with value: -5965.3822188922995.
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# [I 2025-03-06 09:02:54,277] Trial 11 finished with value: -5853.793466320408 and parameters: {'n_clusters': 2, 'contamination': 0.01777142798847969}. Best is trial 10 with value: -5965.3822188922995.
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# [I 2025-03-06 09:02:54,596] Trial 12 finished with value: -6058.380762504196 and parameters: {'n_clusters': 2, 'contamination': 0.01306188559965239}. Best is trial 12 with value: -6058.380762504196.
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# [I 2025-03-06 09:02:54,911] Trial 13 finished with value: -5936.7066342381695 and parameters: {'n_clusters': 2, 'contamination': 0.014651901228762964}. Best is trial 12 with value: -6058.380762504196.
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# [I 2025-03-06 09:02:55,217] Trial 14 finished with value: -3419.1296402504645 and parameters: {'n_clusters': 6, 'contamination': 0.04281154919072665}. Best is trial 12 with value: -6058.380762504196.
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# [I 2025-03-06 09:02:55,520] Trial 15 finished with value: -6127.43349484686 and parameters: {'n_clusters': 2, 'contamination': 0.010276890673934978}. Best is trial 15 with value: -6127.43349484686.
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# [I 2025-03-06 09:02:55,825] Trial 16 finished with value: -3587.2269715553957 and parameters: {'n_clusters': 3, 'contamination': 0.11906293765187292}. Best is trial 15 with value: -6127.43349484686.
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# [I 2025-03-06 09:02:56,147] Trial 17 finished with value: -3773.52264085646 and parameters: {'n_clusters': 5, 'contamination': 0.038046273328678964}. Best is trial 15 with value: -6127.43349484686.
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# [I 2025-03-06 09:02:56,590] Trial 18 finished with value: -2749.9358804498256 and parameters: {'n_clusters': 8, 'contamination': 0.06843935356011713}. Best is trial 15 with value: -6127.43349484686.
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# [I 2025-03-06 09:02:57,083] Trial 19 finished with value: -5410.655950755397 and parameters: {'n_clusters': 2, 'contamination': 0.030510578675453235}. Best is trial 15 with value: -6127.43349484686.
# ✅ Best Parameters Found: {'n_clusters': 2, 'contamination': 0.010276890673934978}
# ✅ Connected to MongoDB successfully!
# ✅ Dataset fetched successfully!
# ✅ Data Cleaning Successful!
# ✅ Data Transformation Successful!
# ✅ Outliers removed successfully using contamination=0.010276890673934978!
# ✅ Clustering Successful with n_clusters=2!
# ❌ Data Saving Failed: bad auth : Authentication failed., full error: {'ok': 0, 'errmsg': 'bad auth : Authentication failed.', 'code': 8000, 'codeName': 'AtlasError'}
# ✅ Visualization Complete!
#
# 📊 **Statistical Analysis:**
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   881.000000  881.000000  881.000000  881.000000  881.000000
# mean     -0.005388   -0.000377    0.006909    0.005883   -0.003935
# std       0.996674    1.000478    0.996302    0.998731    0.999628
# min      -1.730108   -0.789272   -1.566107   -1.355574   -2.199116
# 25%      -0.866998   -0.789272   -0.369365   -1.355574   -0.592588
# 50%      -0.003888   -0.789272    0.827377    0.737695   -0.059082
# 75%       0.851446    1.266990    0.827377    0.737695    0.474424
# max       1.730108    1.266990    0.827377    0.737695    3.780656
#
#             SibSp       Parch        Fare    Embarked     Cluster
# count  881.000000  881.000000  881.000000  881.000000  881.000000
# mean    -0.030660   -0.028439   -0.039808    0.003414    0.629966
# std      0.915625    0.958460    0.883376    0.998425    0.483088
# min     -0.474545   -0.473674   -0.648422   -1.938460    0.000000
# 25%     -0.474545   -0.473674   -0.489442   -0.678673    0.000000
# 50%     -0.474545   -0.473674   -0.357391    0.581114    1.000000
# 75%      0.432793   -0.473674   -0.034314    0.581114    1.000000
# max      6.784163    6.974147    9.667167    1.840901    1.000000
#
# 🔢 **Feature Correlation:**
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.001180 -0.044392  0.049103  0.037699 -0.093365
# Survived       -0.001180  1.000000 -0.334609 -0.547444 -0.064368 -0.023966
# Pclass         -0.044392 -0.334609  1.000000  0.134005 -0.340385  0.085874
# Sex             0.049103 -0.547444  0.134005  1.000000  0.076834 -0.104606
# Age             0.037699 -0.064368 -0.340385  0.076834  1.000000 -0.257535
# SibSp          -0.093365 -0.023966  0.085874 -0.104606 -0.257535  1.000000
# Parch          -0.019410  0.093057  0.032960 -0.242219 -0.202238  0.407484
# Fare            0.013144  0.268000 -0.567709 -0.200901  0.106669  0.133619
# Embarked        0.017082 -0.156197  0.151603  0.101458 -0.022839  0.060590
# Cluster        -0.015166 -0.811870  0.402637  0.700239  0.072644 -0.087448
#
#                 Parch      Fare  Embarked   Cluster
# PassengerId -0.019410  0.013144  0.017082 -0.015166
# Survived     0.093057  0.268000 -0.156197 -0.811870
# Pclass       0.032960 -0.567709  0.151603  0.402637
# Sex         -0.242219 -0.200901  0.101458  0.700239
# Age         -0.202238  0.106669 -0.022839  0.072644
# SibSp        0.407484  0.133619  0.060590 -0.087448
# Parch        1.000000  0.163604  0.046253 -0.301810
# Fare         0.163604  1.000000 -0.218697 -0.376589
# Embarked     0.046253 -0.218697  1.000000  0.197395
# Cluster     -0.301810 -0.376589  0.197395  1.000000
# ✅ Statistical Analysis Complete!

# %%
# -------------------- IMPORTS -------------------- #
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import joblib
import logging
import optuna
from io import BytesIO, StringIO
import base64
from datetime import datetime
from typing import Tuple, Dict, Any
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.cluster import KMeans
from sklearn.ensemble import IsolationForest
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from flask import Flask, render_template_string, send_file
from pyngrok import ngrok
import warnings
warnings.filterwarnings("ignore")

# -------------------- CONFIGURATION -------------------- #
class Config:
    DATA_URL = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
    NUMERICAL_FEATURES = ['Age', 'Fare', 'SibSp', 'Parch']
    CATEGORICAL_FEATURES = ['Sex', 'Embarked', 'Pclass']
    DROP_FEATURES = ['Name', 'Ticket', 'Cabin', 'PassengerId']
    OPTUNA_TRIALS = 10
    CONTAMINATION_RANGE = (0.05, 0.2)
    N_CLUSTERS_RANGE = (2, 6)
    PORT = 5001
    ARTIFACT_PATH = "/content/artifacts"
    PLOT_STYLE = "whitegrid"
    COLOR_PALETTE = "viridis"

# -------------------- ENHANCED PIPELINE -------------------- #
class EnhancedETL:
    def __init__(self):
        self.preprocessor = None
        self.best_params = None

    def _create_preprocessor(self) -> ColumnTransformer:
        numerical_pipe = Pipeline([
            ('imputer', KNNImputer(n_neighbors=5)),
            ('scaler', StandardScaler())
        ])

        categorical_pipe = Pipeline([
            ('encoder', OneHotEncoder(handle_unknown='ignore'))
        ])

        return ColumnTransformer([
            ('num', numerical_pipe, Config.NUMERICAL_FEATURES),
            ('cat', categorical_pipe, Config.CATEGORICAL_FEATURES)
        ])

    def optimize_hyperparameters(self, X: pd.DataFrame) -> Dict[str, Any]:
        def objective(trial: optuna.Trial) -> float:
            contamination = trial.suggest_float('contamination', *Config.CONTAMINATION_RANGE)
            n_clusters = trial.suggest_int('n_clusters', *Config.N_CLUSTERS_RANGE)

            X_processed = self.preprocessor.fit_transform(X)
            iso = IsolationForest(contamination=contamination)
            mask = iso.fit_predict(X_processed) == 1
            kmeans = KMeans(n_clusters=n_clusters, n_init=10)
            kmeans.fit(X_processed[mask])
            return kmeans.inertia_

        study = optuna.create_study(direction='minimize')
        study.optimize(objective, n_trials=Config.OPTUNA_TRIALS)
        self.best_params = study.best_params
        return self.best_params

    def run_pipeline(self, df: pd.DataFrame) -> pd.DataFrame:
        self.preprocessor = self._create_preprocessor()
        best_params = self.optimize_hyperparameters(df)
        X_processed = self.preprocessor.fit_transform(df)

        iso = IsolationForest(contamination=best_params['contamination'])
        mask = iso.fit_predict(X_processed) == 1
        df_clean = df[mask].copy()

        kmeans = KMeans(n_clusters=best_params['n_clusters'], n_init=10)
        df_clean['Cluster'] = kmeans.fit_predict(self.preprocessor.transform(df_clean))

        joblib.dump(self.preprocessor, f"{Config.ARTIFACT_PATH}/preprocessor.joblib")
        df_clean.to_parquet(f"{Config.ARTIFACT_PATH}/processed_data.parquet")
        df_clean.to_csv(f"{Config.ARTIFACT_PATH}/processed_data.csv", index=False)

        return df_clean

# -------------------- PROFESSIONAL DASHBOARD -------------------- #
app = Flask(__name__)
sns.set_style(Config.PLOT_STYLE)
sns.set_palette(Config.COLOR_PALETTE)
processed_data = None

def create_plot(figsize=(10,6)):
    plt.figure(figsize=figsize)
    plt.tight_layout()
    return plt

@app.route('/')
def dashboard():
    return render_template_string('''
    <!DOCTYPE html>
    <html>
    <head>
        <title>AI ETL Dashboard</title>
        <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.1.3/dist/css/bootstrap.min.css" rel="stylesheet">
        <style>
            .card { margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1); }
            .plot-img { width: 100%; height: auto; border-radius: 8px; }
            .stats-card { background: #f8f9fa; padding: 20px; border-radius: 8px; }
        </style>
    </head>
    <body class="container mt-4">
        <h1 class="mb-4 text-center">AI-Driven ETL Analysis Dashboard</h1>

        <div class="row">
            <div class="col-md-12">
                <div class="card">
                    <div class="card-body">
                        <h4 class="card-title">Quick Actions</h4>
                        <a href="/cluster_analysis" class="btn btn-primary">Cluster Analysis</a>
                        <a href="/distribution" class="btn btn-info">Distributions</a>
                        <a href="/correlation" class="btn btn-success">Correlations</a>
                        <a href="/download" class="btn btn-secondary">Download Data</a>
                    </div>
                </div>
            </div>
        </div>

        <div class="row">
            <div class="col-md-12">
                <div class="stats-card">
                    <h4>Key Statistics</h4>
                    {{ stats_table|safe }}
                </div>
            </div>
        </div>
    </body>
    </html>
    ''', stats_table=processed_data.describe().to_html(classes="table table-striped"))

@app.route('/cluster_analysis')
def cluster_analysis():
    try:
        plt = create_plot((12,6))
        g = sns.pairplot(processed_data, hue='Cluster', corner=True)
        g.fig.suptitle("Cluster Pairwise Relationships", y=1.02)
        img = BytesIO()
        plt.savefig(img, format='png', bbox_inches='tight')
        img.seek(0)
        return render_template(f'<img class="plot-img" src="data:image/png;base64,{base64.b64encode(img.getvalue()).decode()}">')
    except Exception as e:
        return error_handler(e)

@app.route('/distribution')
def distribution_analysis():
    try:
        plt = create_plot()
        fig, axes = plt.subplots(2, 2, figsize=(12,8))

        # Age Distribution
        sns.histplot(processed_data['Age'], kde=True, ax=axes[0,0])
        axes[0,0].set_title('Age Distribution')

        # Fare Distribution
        sns.boxplot(x=processed_data['Fare'], ax=axes[0,1])
        axes[0,1].set_title('Fare Distribution')

        # Cluster Distribution
        sns.countplot(x='Cluster', data=processed_data, ax=axes[1,0])
        axes[1,0].set_title('Cluster Distribution')

        # Class Distribution
        sns.countplot(x='Pclass', data=processed_data, ax=axes[1,1])
        axes[1,1].set_title('Class Distribution')

        img = BytesIO()
        plt.savefig(img, format='png', bbox_inches='tight')
        img.seek(0)
        return render_image(img)
    except Exception as e:
        return error_handler(e)

@app.route('/correlation')
def correlation_analysis():
    try:
        plt = create_plot((10,8))
        corr_matrix = processed_data.corr()
        sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
        plt.title("Feature Correlation Matrix")
        return render_image(plt)
    except Exception as e:
        return error_handler(e)

@app.route('/download')
def download():
    try:
        return send_file(
            f"{Config.ARTIFACT_PATH}/processed_data.csv",
            mimetype='text/csv',
            as_attachment=True,
            download_name=f"processed_data_{datetime.now().strftime('%Y%m%d')}.csv"
        )
    except Exception as e:
        return error_handler(e)

def render_image(plt):
    img = BytesIO()
    plt.savefig(img, format='png', bbox_inches='tight')
    img.seek(0)
    plt.close()
    return f'<img class="plot-img" src="data:image/png;base64,{base64.b64encode(img.getvalue()).decode()}">'

def error_handler(e):
    return f'''
    <div class="alert alert-danger">
        <h4>Error Occurred</h4>
        <pre>{str(e)}</pre>
        <a href="/" class="btn btn-primary">Return to Dashboard</a>
    </div>
    '''

# -------------------- MAIN EXECUTION -------------------- #
def main():
    global processed_data

    # Colab setup
    # !mkdir -p {Config.ARTIFACT_PATH}
    # !pip install -q flask pyngrok optuna scikit-learn pyarrow
    # !ngrok authtoken 2twHHIhppxwLpGPDYSu6Gxs8zUE_4qhDG5cJsWk8H3J6wSut3

    # Run pipeline
    raw_data = pd.read_csv(Config.DATA_URL).drop(Config.DROP_FEATURES, axis=1)
    processed_data = EnhancedETL().run_pipeline(raw_data)

    # Start server
    public_url = ngrok.connect(Config.PORT).public_url
    print(f"🌐 Dashboard URL: {public_url}")
    app.run(host='0.0.0.0', port=Config.PORT)

if __name__ == "__main__":
    main()
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# [I 2025-03-06 20:10:09,740] A new study created in memory with name: no-name-eb291803-9983-4483-8edc-2c12e9e94a3a
# [I 2025-03-06 20:10:10,062] Trial 0 finished with value: 2116.0927140910476 and parameters: {'contamination': 0.14622692051627276, 'n_clusters': 2}. Best is trial 0 with value: 2116.0927140910476.
# [I 2025-03-06 20:10:10,389] Trial 1 finished with value: 1296.3334133167436 and parameters: {'contamination': 0.19338772264291149, 'n_clusters': 4}. Best is trial 1 with value: 1296.3334133167436.
# [I 2025-03-06 20:10:10,697] Trial 2 finished with value: 2053.3364426413455 and parameters: {'contamination': 0.0916481045482472, 'n_clusters': 3}. Best is trial 1 with value: 1296.3334133167436.
# [I 2025-03-06 20:10:11,021] Trial 3 finished with value: 1287.7930525838829 and parameters: {'contamination': 0.16371120548570617, 'n_clusters': 5}. Best is trial 3 with value: 1287.7930525838829.
# [I 2025-03-06 20:10:11,369] Trial 4 finished with value: 1108.3590307172863 and parameters: {'contamination': 0.17393356418290767, 'n_clusters': 6}. Best is trial 4 with value: 1108.3590307172863.
# [I 2025-03-06 20:10:11,684] Trial 5 finished with value: 1556.6028075962174 and parameters: {'contamination': 0.14050176522047667, 'n_clusters': 4}. Best is trial 4 with value: 1108.3590307172863.
# [I 2025-03-06 20:10:12,006] Trial 6 finished with value: 1451.6965407567404 and parameters: {'contamination': 0.1314333805787773, 'n_clusters': 5}. Best is trial 4 with value: 1108.3590307172863.
# [I 2025-03-06 20:10:12,335] Trial 7 finished with value: 2299.505471368218 and parameters: {'contamination': 0.05289180459935797, 'n_clusters': 3}. Best is trial 4 with value: 1108.3590307172863.
# [I 2025-03-06 20:10:12,675] Trial 8 finished with value: 2011.8517386797623 and parameters: {'contamination': 0.09601622524337045, 'n_clusters': 3}. Best is trial 4 with value: 1108.3590307172863.
# [I 2025-03-06 20:10:13,005] Trial 9 finished with value: 2295.0024776126393 and parameters: {'contamination': 0.05528253400956109, 'n_clusters': 3}. Best is trial 4 with value: 1108.3590307172863.
# 🌐 Dashboard URL: https://4512-34-148-100-244.ngrok-free.app
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5001
#  * Running on http://172.28.0.12:5001
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [06/Mar/2025 20:10:22] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Mar/2025 20:10:23] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [06/Mar/2025 20:10:38] "GET /cluster_analysis HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Mar/2025 20:10:41] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Mar/2025 20:10:45] "GET /distribution HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Mar/2025 20:10:50] "GET /correlation HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [06/Mar/2025 20:10:55] "GET /download HTTP/1.1" 200 -

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.2.1-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.15.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.38)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.9-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.2.1-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 22.1 MB/s eta 0:00:00
# Downloading alembic-1.15.1-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.8/231.8 kB 15.4 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 4.9 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.9 alembic-1.15.1 colorlog-6.9.0 optuna-4.2.1

# %%
# !pip install pyngrok
# Out:
# Collecting pyngrok
#   Downloading pyngrok-7.2.3-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from pyngrok) (6.0.2)
# Downloading pyngrok-7.2.3-py3-none-any.whl (23 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.2.3

# %%
# -------------------- IMPORTS -------------------- #
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # For 3D plots
import joblib
import logging
import optuna
from io import BytesIO, StringIO
import base64
from datetime import datetime
from typing import Tuple, Dict, Any
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.cluster import KMeans
from sklearn.ensemble import IsolationForest
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from flask import Flask, render_template_string, send_file
from pyngrok import ngrok
import warnings
warnings.filterwarnings("ignore")

# -------------------- CONFIGURATION -------------------- #
class Config:
    DATA_URL = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
    NUMERICAL_FEATURES = ['Age', 'Fare', 'SibSp', 'Parch']
    CATEGORICAL_FEATURES = ['Sex', 'Embarked', 'Pclass']
    DROP_FEATURES = ['Name', 'Ticket', 'Cabin', 'PassengerId']
    OPTUNA_TRIALS = 10
    CONTAMINATION_RANGE = (0.05, 0.2)
    N_CLUSTERS_RANGE = (2, 6)
    PORT = 5001
    ARTIFACT_PATH = "/content/artifacts"
    PLOT_STYLE = "whitegrid"
    COLOR_PALETTE = "muted"
    PLOT_SIZE = (14, 8)

# -------------------- ENHANCED PIPELINE -------------------- #
class ProductionETL:
    def __init__(self):
        self.preprocessor = None
        self.best_params = None

    def _create_preprocessor(self) -> ColumnTransformer:
        numerical_pipe = Pipeline([
            ('imputer', KNNImputer(n_neighbors=5)),
            ('scaler', StandardScaler())
        ])

        categorical_pipe = Pipeline([
            ('encoder', OneHotEncoder(handle_unknown='ignore'))
        ])

        return ColumnTransformer([
            ('num', numerical_pipe, Config.NUMERICAL_FEATURES),
            ('cat', categorical_pipe, Config.CATEGORICAL_FEATURES)
        ])

    def optimize_hyperparameters(self, X: pd.DataFrame) -> Dict[str, Any]:
        def objective(trial: optuna.Trial) -> float:
            contamination = trial.suggest_float('contamination', *Config.CONTAMINATION_RANGE)
            n_clusters = trial.suggest_int('n_clusters', *Config.N_CLUSTERS_RANGE)

            X_processed = self.preprocessor.fit_transform(X)
            iso = IsolationForest(contamination=contamination)
            mask = iso.fit_predict(X_processed) == 1
            kmeans = KMeans(n_clusters=n_clusters, n_init=10)
            kmeans.fit(X_processed[mask])
            return kmeans.inertia_

        study = optuna.create_study(direction='minimize')
        study.optimize(objective, n_trials=Config.OPTUNA_TRIALS)
        self.best_params = study.best_params
        return self.best_params

    def run_pipeline(self, df: pd.DataFrame) -> pd.DataFrame:
        self.preprocessor = self._create_preprocessor()
        best_params = self.optimize_hyperparameters(df)
        X_processed = self.preprocessor.fit_transform(df)

        iso = IsolationForest(contamination=best_params['contamination'])
        mask = iso.fit_predict(X_processed) == 1
        df_clean = df[mask].copy()

        kmeans = KMeans(n_clusters=best_params['n_clusters'], n_init=10)
        df_clean['Cluster'] = kmeans.fit_predict(self.preprocessor.transform(df_clean))

        joblib.dump(self.preprocessor, f"{Config.ARTIFACT_PATH}/preprocessor.joblib")
        df_clean.to_parquet(f"{Config.ARTIFACT_PATH}/processed_data.parquet")
        df_clean.to_csv(f"{Config.ARTIFACT_PATH}/processed_data.csv", index=False)

        return df_clean

# -------------------- PROFESSIONAL DASHBOARD -------------------- #
app = Flask(__name__)
sns.set_style(Config.PLOT_STYLE)
sns.set_palette(Config.COLOR_PALETTE)
processed_data = None

def create_plot():
    plt.figure(figsize=Config.PLOT_SIZE)
    return plt

def render_plot(plt):
    img = BytesIO()
    plt.savefig(img, format='png', bbox_inches='tight', dpi=100)
    img.seek(0)
    plt.close()
    return base64.b64encode(img.getvalue()).decode()

def generate_stats(df):
    try:
        # Convert numeric columns
        numeric_df = df.select_dtypes(include=[np.number])

        # Calculate statistics
        stats = numeric_df.describe().T
        stats['skew'] = numeric_df.skew()
        stats['kurtosis'] = numeric_df.kurtosis()
        stats['missing'] = numeric_df.isnull().sum()

        return stats
    except Exception as e:
        print(f"Error generating stats: {e}")
        return pd.DataFrame()

def create_nav():
    return '''
    <nav class="navbar navbar-expand-lg navbar-dark bg-dark mb-4">
        <div class="container-fluid">
            <a class="navbar-brand" href="/">AI ETL Dashboard</a>
            <button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#navbarNav">
                <span class="navbar-toggler-icon"></span>
            </button>
            <div class="collapse navbar-collapse" id="navbarNav">
                <ul class="navbar-nav">
                    <li class="nav-item">
                        <a class="nav-link" href="/cluster">Clusters</a>
                    </li>
                    <li class="nav-item">
                        <a class="nav-link" href="/distribution">Distributions</a>
                    </li>
                    <li class="nav-item">
                        <a class="nav-link" href="/correlation">Correlations</a>
                    </li>
                    <li class="nav-item">
                        <a class="nav-link" href="/stats">Statistics</a>
                    </li>
                    <li class="nav-item">
                        <a class="nav-link" href="/download">Download</a>
                    </li>
                </ul>
            </div>
        </div>
    </nav>
    '''

@app.route('/')
def dashboard():
    return render_template_string(f'''
    <!DOCTYPE html>
    <html>
    <head>
        <title>AI ETL Dashboard</title>
        <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.1.3/dist/css/bootstrap.min.css" rel="stylesheet">
        <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.0.0/css/all.min.css" rel="stylesheet">
        <style>
            .card {{ margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1); transition: transform 0.2s; }}
            .card:hover {{ transform: translateY(-5px); }}
            .plot-img {{ width: 100%; height: auto; border-radius: 8px; border: 1px solid #ddd; }}
            .stats-table {{ max-height: 600px; overflow-y: auto; }}
        </style>
    </head>
    <body>
        {create_nav()}

        <div class="container">
            <div class="row">
                <div class="col-md-12">
                    <div class="card">
                        <div class="card-body">
                            <h4><i class="fas fa-info-circle"></i> Dataset Overview</h4>
                            <div class="row">
                                <div class="col-md-4">
                                    <div class="alert alert-primary">
                                        <h5>Total Samples</h5>
                                        <h3>{len(processed_data):,}</h3>
                                    </div>
                                </div>
                                <div class="col-md-4">
                                    <div class="alert alert-success">
                                        <h5>Features</h5>
                                        <h3>{len(processed_data.columns)}</h3>
                                    </div>
                                </div>
                                <div class="col-md-4">
                                    <div class="alert alert-info">
                                        <h5>Clusters</h5>
                                        <h3>{processed_data['Cluster'].nunique()}</h3>
                                    </div>
                                </div>
                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </div>
    </body>
    </html>
    ''')

@app.route('/cluster')
def cluster_analysis():
    try:
        # Cluster Distribution
        plt1 = create_plot()
        sns.countplot(x='Cluster', data=processed_data)
        plt.title('Cluster Distribution')
        img1 = render_plot(plt1)

        # Cluster Characteristics
        plt2 = create_plot()
        sns.boxplot(x='Cluster', y='Age', data=processed_data)
        plt.title('Age Distribution by Cluster')
        img2 = render_plot(plt2)

        # 3D Visualization
        plt3 = create_plot()
        ax = plt3.figure().add_subplot(111, projection='3d')  # Fixed 3D plot
        ax.scatter(
            processed_data['Age'],
            processed_data['Fare'],
            processed_data['SibSp'],
            c=processed_data['Cluster'],
            cmap='viridis'
        )
        ax.set_xlabel('Age')
        ax.set_ylabel('Fare')
        ax.set_zlabel('Siblings/Spouses')
        img3 = render_plot(plt3)

        return render_template_string(f'''
        {create_nav()}
         <style>
            .card {{ margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1); transition: transform 0.2s; }}
            .card:hover {{ transform: translateY(-5px); }}
            .plot-img {{ width: 100%; height: auto; border-radius: 8px; border: 1px solid #ddd; }}
            .stats-table {{ max-height: 600px; overflow-y: auto; }}
        </style>
        <div class="container">
            <h3 class="mb-4"><i class="fas fa-chart-pie"></i> Cluster Analysis</h3>
            <div class="row">
                <div class="col-md-4">
                    <div class="card">
                        <div class="card-body">
                            <img src="data:image/png;base64,{img1}" class="plot-img">
                        </div>
                    </div>
                </div>
                <div class="col-md-8">
                    <div class="card">
                        <div class="card-body">
                            <img src="data:image/png;base64,{img2}" class="plot-img">
                        </div>
                    </div>
                </div>
            </div>
            <div class="row mt-4">
                <div class="col-md-12">
                    <div class="card">
                        <div class="card-body">
                            <h5>3D Cluster Visualization</h5>
                            <img src="data:image/png;base64,{img3}" class="plot-img">
                        </div>
                    </div>
                </div>
            </div>
        </div>
        ''')
    except Exception as e:
        return error_handler(e)

@app.route('/distribution')
def distribution_analysis():
    try:
        # Age Distribution
        plt1 = create_plot()
        sns.histplot(processed_data['Age'], kde=True, bins=30)
        plt.title('Age Distribution')
        img1 = render_plot(plt1)

        # Fare Distribution
        plt2 = create_plot()
        sns.boxplot(x=processed_data['Fare'])
        plt.title('Fare Distribution')
        img2 = render_plot(plt2)

        # Combined Distribution
        plt3 = create_plot()
        fig, axes = plt.subplots(2, 2, figsize=(14, 10))
        sns.histplot(processed_data['SibSp'], kde=True, ax=axes[0,0])
        sns.histplot(processed_data['Parch'], kde=True, ax=axes[0,1])
        sns.countplot(x='Sex', data=processed_data, ax=axes[1,0])
        sns.countplot(x='Pclass', data=processed_data, ax=axes[1,1])
        plt.tight_layout()
        img3 = render_plot(plt3)

        return render_template_string(f'''
        {create_nav()}
        <style>
            .card {{ margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1); transition: transform 0.2s; }}
            .card:hover {{ transform: translateY(-5px); }}
            .plot-img {{ width: 100%; height: auto; border-radius: 8px; border: 1px solid #ddd; }}
            .stats-table {{ max-height: 600px; overflow-y: auto; }}
        </style>
        <div class="container">
            <h3 class="mb-4"><i class="fas fa-chart-bar"></i> Feature Distributions</h3>
            <div class="row">
                <div class="col-md-6">
                    <div class="card">
                        <div class="card-body">
                            <img src="data:image/png;base64,{img1}" class="plot-img">
                        </div>
                    </div>
                </div>
                <div class="col-md-6">
                    <div class="card">
                        <div class="card-body">
                            <img src="data:image/png;base64,{img2}" class="plot-img">
                        </div>
                    </div>
                </div>
            </div>
            <div class="row mt-4">
                <div class="col-md-12">
                    <div class="card">
                        <div class="card-body">
                            <img src="data:image/png;base64,{img3}" class="plot-img">
                        </div>
                    </div>
                </div>
            </div>
        </div>
        ''')
    except Exception as e:
        return error_handler(e)

@app.route('/correlation')
def correlation_analysis():
    try:
        # Correlation Matrix
        plt1 = create_plot()
        corr = processed_data.corr()
        sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
        plt.title('Feature Correlation Matrix')
        img1 = render_plot(plt1)

        # Cluster Correlation
        plt2 = create_plot()
        cluster_corr = processed_data.groupby('Cluster').mean().corr()
        sns.heatmap(cluster_corr, annot=True, fmt=".2f", cmap="viridis")
        plt.title('Cluster-wise Correlation')
        img2 = render_plot(plt2)

        return render_template_string(f'''
        {create_nav()}
        <style>
            .card {{ margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1); transition: transform 0.2s; }}
            .card:hover {{ transform: translateY(-5px); }}
            .plot-img {{ width: 100%; height: auto; border-radius: 8px; border: 1px solid #ddd; }}
            .stats-table {{ max-height: 600px; overflow-y: auto; }}
        </style>
        <div class="container">
            <h3 class="mb-4"><i class="fas fa-project-diagram"></i> Correlation Analysis</h3>
            <div class="row">
                <div class="col-md-12">
                    <div class="card">
                        <div class="card-body">
                            <img src="data:image/png;base64,{img1}" class="plot-img">
                        </div>
                    </div>
                </div>
            </div>
            <div class="row mt-4">
                <div class="col-md-12">
                    <div class="card">
                        <div class="card-body">
                            <img src="data:image/png;base64,{img2}" class="plot-img">
                        </div>
                    </div>
                </div>
            </div>
        </div>
        ''')
    except Exception as e:
        return error_handler(e)

@app.route('/stats')
def statistical_analysis():
    try:
        stats = generate_stats(processed_data)
        return render_template_string(f'''
        {create_nav()}
        <style>
            .card {{ margin: 20px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1); transition: transform 0.2s; }}
            .card:hover {{ transform: translateY(-5px); }}
            .plot-img {{ width: 100%; height: auto; border-radius: 8px; border: 1px solid #ddd; }}
            .stats-table {{ max-height: 600px; overflow-y: auto; }}
        </style>
        <div class="container">
            <h3 class="mb-4"><i class="fas fa-calculator"></i> Statistical Analysis</h3>
            <div class="card">
                <div class="card-body stats-table">
                    {stats.to_html(classes="table table-striped table-hover")}
                </div>
            </div>
            <div class="row mt-4">
                <div class="col-md-6">
                    <div class="card">
                        <div class="card-body">
                            <h5>Skewness Analysis</h5>
                            <ul class="list-group">
                                {"".join(f'<li class="list-group-item d-flex justify-content-between align-items-center">{col}<span class="badge bg-primary rounded-pill">{stats.loc[col,"skew"]:.2f}</span></li>' for col in stats.index)}
                            </ul>
                        </div>
                    </div>
                </div>
                <div class="col-md-6">
                    <div class="card">
                        <div class="card-body">
                            <h5>Kurtosis Analysis</h5>
                            <ul class="list-group">
                                {"".join(f'<li class="list-group-item d-flex justify-content-between align-items-center">{col}<span class="badge bg-success rounded-pill">{stats.loc[col,"kurtosis"]:.2f}</span></li>' for col in stats.index)}
                            </ul>
                        </div>
                    </div>
                </div>
            </div>
        </div>
        ''')
    except Exception as e:
        return error_handler(e)

@app.route('/download')
def download_data():
    try:
        return send_file(
            f"{Config.ARTIFACT_PATH}/processed_data.csv",
            mimetype='text/csv',
            as_attachment=True,
            download_name=f"processed_data_{datetime.now().strftime('%Y%m%d')}.csv"
        )
    except Exception as e:
        return error_handler(e)

def error_handler(e):
    return f'''
    {create_nav()}
    <div class="container">
        <div class="alert alert-danger mt-4">
            <h4><i class="fas fa-exclamation-triangle"></i> Error Occurred</h4>
            <pre>{str(e)}</pre>
            <a href="/" class="btn btn-primary">
                <i class="fas fa-home"></i> Return to Dashboard
            </a>
        </div>
    </div>
    '''

# -------------------- MAIN EXECUTION -------------------- #
def main():
    global processed_data

    # Colab setup
    # !mkdir -p {Config.ARTIFACT_PATH}
    # !pip install -q flask pyngrok optuna scikit-learn pyarrow
    # !ngrok authtoken 2twHHIhppxwLpGPDYSu6Gxs8zUE_4qhDG5cJsWk8H3J6wSut3
    # Run pipeline
    raw_data = pd.read_csv(Config.DATA_URL).drop(Config.DROP_FEATURES, axis=1)
    etl = ProductionETL()
    processed_data = etl.run_pipeline(raw_data)

    # Start server
    public_url = ngrok.connect(Config.PORT).public_url
    print(f"\U0001F30D Dashboard URL: {public_url}")
    app.run(host='0.0.0.0', port=Config.PORT)

if __name__ == "__main__":
    main()
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# [I 2025-03-07 02:03:28,425] A new study created in memory with name: no-name-51e81c17-41bf-4856-bed1-86c2faf9f8a8
# [I 2025-03-07 02:03:28,980] Trial 0 finished with value: 1532.2266385092666 and parameters: {'contamination': 0.08095959834596844, 'n_clusters': 6}. Best is trial 0 with value: 1532.2266385092666.
# [I 2025-03-07 02:03:29,512] Trial 1 finished with value: 1379.3627388145712 and parameters: {'contamination': 0.17851873766928528, 'n_clusters': 4}. Best is trial 1 with value: 1379.3627388145712.
# [I 2025-03-07 02:03:30,027] Trial 2 finished with value: 1394.9937882823529 and parameters: {'contamination': 0.1832188524356017, 'n_clusters': 4}. Best is trial 1 with value: 1379.3627388145712.
# [I 2025-03-07 02:03:30,590] Trial 3 finished with value: 1333.0540308648513 and parameters: {'contamination': 0.14634669127012606, 'n_clusters': 5}. Best is trial 3 with value: 1333.0540308648513.
# [I 2025-03-07 02:03:31,155] Trial 4 finished with value: 1896.8184506420391 and parameters: {'contamination': 0.12139671918754623, 'n_clusters': 3}. Best is trial 3 with value: 1333.0540308648513.
# [I 2025-03-07 02:03:31,727] Trial 5 finished with value: 2239.0450204072986 and parameters: {'contamination': 0.06655856534106872, 'n_clusters': 3}. Best is trial 3 with value: 1333.0540308648513.
# [I 2025-03-07 02:03:32,115] Trial 6 finished with value: 2809.5049253426205 and parameters: {'contamination': 0.05567499037520395, 'n_clusters': 2}. Best is trial 3 with value: 1333.0540308648513.
# [I 2025-03-07 02:03:32,470] Trial 7 finished with value: 1584.6788136982566 and parameters: {'contamination': 0.10714195451431825, 'n_clusters': 5}. Best is trial 3 with value: 1333.0540308648513.
# [I 2025-03-07 02:03:32,803] Trial 8 finished with value: 1996.545951608936 and parameters: {'contamination': 0.0608738686419819, 'n_clusters': 4}. Best is trial 3 with value: 1333.0540308648513.
# [I 2025-03-07 02:03:33,128] Trial 9 finished with value: 2258.7120596280024 and parameters: {'contamination': 0.06384216783087751, 'n_clusters': 3}. Best is trial 3 with value: 1333.0540308648513.
# 🌍 Dashboard URL: https://ac36-34-150-152-245.ngrok-free.app
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5001
#  * Running on http://172.28.0.12:5001
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [07/Mar/2025 02:03:42] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [07/Mar/2025 02:03:44] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [07/Mar/2025 02:03:47] "GET /cluster HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [07/Mar/2025 02:03:59] "GET /distribution HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [07/Mar/2025 02:04:05] "GET /correlation HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [07/Mar/2025 02:04:08] "GET /stats HTTP/1.1" 200 -
